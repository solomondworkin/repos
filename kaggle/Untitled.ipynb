# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
# Untitled.ipynb
# house-prices-advanced-regression-techniques/
# layoffs_data.csv

# %%
df = pd.read_csv('layoffs_data.csv')

# %%
df
# Out:
#               Company        Location        Industry  Percentage        Date  \
# 0            Bilibili        Shanghai           Media        0.30  2022-12-27
# 1     Octopus Network     Beau Vallon          Crypto        0.40  2022-12-27
# 2                PayU       Amsterdam         Finance        0.06  2022-12-26
# 3         Back Market           Paris          Retail        0.13  2022-12-23
# 4              Zoopla          London     Real Estate         NaN  2022-12-23
# ...               ...             ...             ...         ...         ...
# 1845     HopSkipDrive     Los Angeles  Transportation        0.10  2020-03-13
# 1846      Panda Squad     SF Bay Area        Consumer        0.75  2020-03-13
# 1847    Tamara Mellon     Los Angeles          Retail        0.40  2020-03-12
# 1848         EasyPost  Salt Lake City       Logistics         NaN  2020-03-11
# 1849        Homebound     SF Bay Area     Real Estate         NaN         NaN
#
# ...

# %%
by_industry = df[['Industry', 'Company']].sort_values('Industry').groupby(by='Industry').count()

# %%
by_industry
# Out:
#                 Company
# Industry
# Aerospace             6
# Construction         14
# Consumer             89
# Crypto               72
# Data                 61
# Education            80
# Energy               11
# Finance             232
# Fitness              27
# Food                116
# HR                   45
# Hardware              2
# Healthcare          134
# Infrastructure       36
# Legal                 9
# Logistics            34
# Marketing           114
# Media                77
# Other                83
# Product              29
# Real Estate         105
# Recruiting           28
# Retail              152
# Sales                27
# Security             55
# Support              27
# Transportation      117
# Travel               62
# Unknown               6
